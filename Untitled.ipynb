# %%
import pandas

# %%
df=pandas.read_csv("traffic.csv")
df
# Out:
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df.iloc[5,1:6]
# Out:
# Visitors       700
# BR              15
# Country      India
# Clicks          32
# Day         Sunday
# Name: 5, dtype: object

# %%
df.drop(8,0)
# Out:
# C:\Users\CARE SYSTEM\AppData\Local\Temp\ipykernel_6508\3766882515.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(8,0)
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 2     3       900  15      India      37   Thursday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 9    10      1400  32  Australia      57   Thursday

# %% [raw]
# df.drop(df.index[2],0)

# %%
df.drop(df.index[2],0)
# Out:
# C:\Users\CARE SYSTEM\AppData\Local\Temp\ipykernel_6508\1173917218.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df.drop(df.index[2],0)
#    Date  Visitors  BR    Country  Clicks        Day
# 0     1      1500  20        USA      20    Tuesday
# 1     2       700  25         UK      35  Wednesday
# 3     4       400  35        USA      12     Friday
# 4     5       500  14     Canada      35   Saturday
# 5     6       700  15      India      32     Sunday
# 6     7       600  20      India      37     Monday
# 7     8       700  16        USA      40    Tuesday
# 8     9      1200  27        USA      52  Wednesday
# 9    10      1400  32  Australia      57   Thursday

# %%
df['status']=["A"]*10
df
# Out:
#    Date  Visitors  BR    Country  Clicks        Day status
# 0     1      1500  20        USA      20    Tuesday      A
# 1     2       700  25         UK      35  Wednesday      A
# 2     3       900  15      India      37   Thursday      A
# 3     4       400  35        USA      12     Friday      A
# 4     5       500  14     Canada      35   Saturday      A
# 5     6       700  15      India      32     Sunday      A
# 6     7       600  20      India      37     Monday      A
# 7     8       700  16        USA      40    Tuesday      A
# 8     9      1200  27        USA      52  Wednesday      A
# 9    10      1400  32  Australia      57   Thursday      A

# %%
df["Test"]=["A"]*df.shape[0]
df
# Out:
#    Date  Visitors  BR    Country  Clicks        Day status Test
# 0     1      1500  20        USA      20    Tuesday      A    A
# 1     2       700  25         UK      35  Wednesday      A    A
# 2     3       900  15      India      37   Thursday      A    A
# 3     4       400  35        USA      12     Friday      A    A
# 4     5       500  14     Canada      35   Saturday      A    A
# 5     6       700  15      India      32     Sunday      A    A
# 6     7       600  20      India      37     Monday      A    A
# 7     8       700  16        USA      40    Tuesday      A    A
# 8     9      1200  27        USA      52  Wednesday      A    A
# 9    10      1400  32  Australia      57   Thursday      A    A

# %%
df["Day"]=df["Day"]+"June"
df
# Out:
#    Date  Visitors  BR    Country  Clicks            Day status Test
# 0     1      1500  20        USA      20    TuesdayJune      A    A
# 1     2       700  25         UK      35  WednesdayJune      A    A
# 2     3       900  15      India      37   ThursdayJune      A    A
# 3     4       400  35        USA      12     FridayJune      A    A
# 4     5       500  14     Canada      35   SaturdayJune      A    A
# 5     6       700  15      India      32     SundayJune      A    A
# 6     7       600  20      India      37     MondayJune      A    A
# 7     8       700  16        USA      40    TuesdayJune      A    A
# 8     9      1200  27        USA      52  WednesdayJune      A    A
# 9    10      1400  32  Australia      57   ThursdayJune      A    A

# %%
df2=df.T
df2
# Out:
#                     0              1             2           3             4  \
# Date                1              2             3           4             5
# Visitors         1500            700           900         400           500
# BR                 20             25            15          35            14
# Country           USA             UK         India         USA        Canada
# Clicks             20             35            37          12            35
# Day       TuesdayJune  WednesdayJune  ThursdayJune  FridayJune  SaturdayJune
# status              A              A             A           A             A
# Test                A              A             A           A             A
#
#                    5           6            7              8             9
# Date               6           7            8              9            10
# Visitors         700         600          700           1200          1400
# ...

# %%
df2["10"]=[11,1200,"USA",36,"Friday"]
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 df2["10"]=[11,1200,"USA",36,"Friday"]
#       2 df2
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
# ...

# %%
df=df2.T
df
# Out:
#   Date Visitors  BR    Country Clicks            Day status Test
# 0    1     1500  20        USA     20    TuesdayJune      A    A
# 1    2      700  25         UK     35  WednesdayJune      A    A
# 2    3      900  15      India     37   ThursdayJune      A    A
# 3    4      400  35        USA     12     FridayJune      A    A
# 4    5      500  14     Canada     35   SaturdayJune      A    A
# 5    6      700  15      India     32     SundayJune      A    A
# 6    7      600  20      India     37     MondayJune      A    A
# 7    8      700  16        USA     40    TuesdayJune      A    A
# 8    9     1200  27        USA     52  WednesdayJune      A    A
# 9   10     1400  32  Australia     57   ThursdayJune      A    A
